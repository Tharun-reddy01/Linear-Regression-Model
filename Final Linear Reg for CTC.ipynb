# %%
#installing dependencies
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data_train = pd.read_csv(Train Data Path)
data_test = pd.read_csv(Test Data Path)

# %%
data_train
# Out:
#       S.No. College       Role  City type  Previous CTC  Previous job changes  \
# 0         1  Tier 1    Manager  Non-Metro       55523.0                   3.0
# 1         2  Tier 2  Executive      Metro       57081.0                   1.0
# 2         3  Tier 2  Executive      Metro       60347.0                   2.0
# 3         4  Tier 3  Executive      Metro       49010.0                   2.0
# 4         5  Tier 3  Executive      Metro       57879.0                   4.0
# ...     ...     ...        ...        ...           ...                   ...
# 1333   1334  Tier 3  Executive      Metro       59661.0                   4.0
# 1334   1335  Tier 1  Executive  Non-Metro       53714.0                   1.0
# 1335   1336  Tier 2  Executive  Non-Metro       61957.0                   1.0
# 1336   1337  Tier 1  Executive  Non-Metro       53203.0                   3.0
# 1337   1338  Tier 3    Manager  Non-Metro       51820.0                   1.0
#
# ...

# %%
data_test
# Out:
#      College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0     Tier 1    Manager  Non-Metro           1           0             1
# 1     Tier 2  Executive      Metro           0           1             0
# 2     Tier 2  Executive      Metro           0           1             0
# 3     Tier 3  Executive      Metro           0           0             0
# 4     Tier 3  Executive      Metro           0           0             0
# ...      ...        ...        ...         ...         ...           ...
# 1333  Tier 3  Executive      Metro           0           0             0
# 1334  Tier 1  Executive  Non-Metro           1           0             0
# 1335  Tier 2  Executive  Non-Metro           0           1             0
# 1336  Tier 1  Executive  Non-Metro           1           0             0
# 1337  Tier 3    Manager  Non-Metro           0           0             1
#
#       City_Metro  Previous CTC  Previous job changes  Graduation marks  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
train_par = data_train.drop(['S.No.','CTC','College','City type','Role'], axis=1)
train_param = train_par.apply(pd.to_numeric, errors='coerce')

train_param
# Out:
#       Previous CTC  Previous job changes  Graduation marks  Exp (Months)
# 0          55523.0                   3.0              66.0          19.0
# 1          57081.0                   1.0              84.0          18.0
# 2          60347.0                   2.0              52.0          28.0
# 3          49010.0                   2.0              81.0          33.0
# 4          57879.0                   4.0              74.0          32.0
# ...            ...                   ...               ...           ...
# 1333       59661.0                   4.0              68.0          50.0
# 1334       53714.0                   1.0              67.0          18.0
# 1335       61957.0                   1.0              47.0          18.0
# 1336       53203.0                   3.0              69.0          21.0
# 1337       51820.0                   1.0              47.0          61.0
#
# [1338 rows x 4 columns]

# %%
train_c = data_train['CTC']
train_ctc = train_c.apply(pd.to_numeric, errors='coerce')

train_ctc
# Out:
# 0       71406.58
# 1       68005.87
# 2       76764.02
# 3       82092.39
# 4       73878.10
#           ...
# 1333    69712.40
# 1334    69298.75
# 1335    66397.77
# 1336    64044.38
# 1337    83346.06
# Name: CTC, Length: 1338, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(train_param, train_ctc)

# %%
regr = LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
data_test
# Out:
#      College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0     Tier 1    Manager  Non-Metro           1           0             1
# 1     Tier 2  Executive      Metro           0           1             0
# 2     Tier 2  Executive      Metro           0           1             0
# 3     Tier 3  Executive      Metro           0           0             0
# 4     Tier 3  Executive      Metro           0           0             0
# ...      ...        ...        ...         ...         ...           ...
# 1333  Tier 3  Executive      Metro           0           0             0
# 1334  Tier 1  Executive  Non-Metro           1           0             0
# 1335  Tier 2  Executive  Non-Metro           0           1             0
# 1336  Tier 1  Executive  Non-Metro           1           0             0
# 1337  Tier 3    Manager  Non-Metro           0           0             1
#
#       City_Metro  Previous CTC  Previous job changes  Graduation marks  \
# ...

# %%
test_da = data_test.drop(['College','Role','City type','College_T1','College_T2','Role_Manager','City_Metro','Actual CTC','Predicted CTC'], axis=1)

test_data = test_da.apply(pd.to_numeric, errors='coerce')

test_data
# Out:
#       Previous CTC  Previous job changes  Graduation marks  Exp (Months)
# 0            55523                     3                66            19
# 1            57081                     1                84            18
# 2            60347                     2                52            28
# 3            49010                     2                81            33
# 4            57879                     4                74            32
# ...            ...                   ...               ...           ...
# 1333         59661                     4                68            50
# 1334         53714                     1                67            18
# 1335         61957                     1                47            18
# 1336         53203                     3                69            21
# 1337         51820                     1                47            61
#
# [1338 rows x 4 columns]

# %%
pred = regr.predict(test_data)

# %%
pred
# Out:
# array([70148.52421425, 70609.72447689, 74481.74594354, ...,
#        72613.46794782, 69556.81922878, 78446.13773644])

# %%
data_test.loc[:,'Predicted CTC'] = pred

# %%
data_test.to_csv('C:/Users/saudq/OneDrive/Desktop/Machine Learning/Task 2/Test_data_file.xlsx - Prediction.csv')

# %%
data_test
# Out:
#      College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0     Tier 1    Manager  Non-Metro           1           0             1
# 1     Tier 2  Executive      Metro           0           1             0
# 2     Tier 2  Executive      Metro           0           1             0
# 3     Tier 3  Executive      Metro           0           0             0
# 4     Tier 3  Executive      Metro           0           0             0
# ...      ...        ...        ...         ...         ...           ...
# 1333  Tier 3  Executive      Metro           0           0             0
# 1334  Tier 1  Executive  Non-Metro           1           0             0
# 1335  Tier 2  Executive  Non-Metro           0           1             0
# 1336  Tier 1  Executive  Non-Metro           1           0             0
# 1337  Tier 3    Manager  Non-Metro           0           0             1
#
#       City_Metro  Previous CTC  Previous job changes  Graduation marks  \
# ...

# %%
mean_squared_error(data_test['Actual CTC'],data_test['Predicted CTC'])
# Out:
# 134470066.20294082
